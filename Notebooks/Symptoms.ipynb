# %% [markdown]
# # Vertical 1: COVID-19 Symptoms

# %% [markdown]
# # Set-up + Importing Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# Suppress seaborn warnings
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.linear_model import LogisticRegressionCV
import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import plot_importance
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, plot_roc_curve, plot_confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm

# %%
path = '/content/drive/My Drive/Blueprint_Datathon/Data/FeverIQ/FeverIQ_PatientData.csv'

feveriq = pd.read_csv(path)
feveriq
# Out:
#       Unnamed: 0  cold  flu  ...  corona_test_result  created_at  country
# 0           3161   0.0  0.1  ...               False  2020-05-06       SI
# 1           3169   0.1  1.0  ...                True  2020-05-06       CN
# 2           3174   2.7  4.7  ...                True  2020-05-06       CN
# 3           3186   0.0  0.1  ...                True  2020-05-06       VN
# 4           3243   2.0  1.0  ...               False  2020-05-06       US
# ...          ...   ...  ...  ...                 ...         ...      ...
# 8198     1033149   0.2  1.1  ...                True  2020-06-30       VN
# 8199     1033151   0.2  1.1  ...                True  2020-06-30       VN
# 8200     1033152   0.0  1.0  ...               False  2020-06-30       ID
# 8201     1033155   0.1  0.1  ...               False  2020-06-30       EG
# 8202     1033156   0.1  1.0  ...               False  2020-06-30       NG
#
# [8203 rows x 8 columns]

# %% [markdown]
# # Data Cleaning + EDA

# %%
# rename ID
feveriq = feveriq.rename(columns={'Unnamed: 0': 'PatientID'})

# %%
# Clean!!
feveriq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8203 entries, 0 to 8202
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PatientID           8203 non-null   int64
#  1   cold                8203 non-null   float64
#  2   flu                 8203 non-null   float64
#  3   corona              8203 non-null   float64
#  4   corona_silent       8203 non-null   float64
#  5   corona_test_result  8203 non-null   bool
#  6   created_at          8203 non-null   object
#  7   country             8203 non-null   object
# dtypes: bool(1), float64(4), int64(1), object(2)
# memory usage: 456.7+ KB

# %%
# Invetigate distributions and relationships
sns.pairplot(feveriq.drop(['PatientID'], axis=1));

# %% [markdown]
# Between cold, flu, and corona, we notice a generally positive linear correlation (i.e. these sypmtoms are associated with each other)
#
# We notice that corona_silent values are discrete on the range [0, 6], so we will treat that variable as categorical and one-hot encode those values, instead of treating it as continuous. We also notice that there is a larger proportion of negative test results, so we need to keep that in mind when we build the model (ensure proportion is maintained)

# %%
# Create Time Series Data grouped by Date
per_date = feveriq.groupby('created_at').mean()
per_date = per_date.drop(['PatientID'], axis=1)
per_date = per_date.reset_index()

# Visualize Time Series Data
plt.figure(figsize=(12, 5))
plt.plot(per_date['created_at'], per_date['cold'], label='cold');
plt.plot(per_date['created_at'], per_date['flu'], label='flu');
plt.plot(per_date['created_at'], per_date['corona'], label='corona');
plt.plot(per_date['created_at'], per_date['corona_silent'], label='corona_silent');
plt.plot(per_date['created_at'], per_date['corona_test_result'], label='corona_test_result');
plt.xticks(rotation=45);
plt.legend();
plt.xlabel('Date');
plt.ylabel('Score')
plt.title('Average Feature Scores and Positive Proportion by Date');

# %% [markdown]
# # Feature Engineering

# %%
# One hot encodes corona_silent, extracts month and day of week, 
# one-hot encodes country
def clean(df):
  # corona_test_results are binary
  df['corona_test_result'] = df['corona_test_result'].astype(int)

  # corona_silent values are discreteized, so will one-hot encode
  df['corona_silent'] = df['corona_silent'].astype(str)
  corona_silent_dummies = pd.get_dummies(df[['PatientID', 'corona_silent']])
  df = df.merge(corona_silent_dummies, on='PatientID')
  df['corona_silent'] = df['corona_silent'].astype(float)
  df = df.drop(['corona_silent'], axis=1)

  # Add month and day of week column, drop date
  df['created_at'] = pd.to_datetime(df['created_at'])
  df['month'] = df['created_at'].dt.month
  df['day_of_week'] = df['created_at'].dt.dayofweek
  ### Drop created_at for now
  df = df.drop(['created_at'], axis=1)

  # One hot encode Country, Month, Day of Week
  df['month'] = df['month'].astype(str)
  df['day_of_week'] = df['day_of_week'].astype(str)
  return pd.get_dummies(df)

df = clean(feveriq)

# %% [markdown]
# ### Preprocessing

# %%
# Returns X and Y (df from clean() above)
def pre_process(df):
  X = df.drop(['corona_test_result', 'PatientID'], axis=1)
  Y = df['corona_test_result']
  return X, Y

# %%
# Gets baseline models (all symptoms only) from clean()
def baseline(X):
  X = X.iloc[:, :10]
  return X

# %%
# returns model with symptoms and interactions between them
def interaction_X(X):
  #X = X.iloc[:, :10]
  num_cols = len(X.columns.values)

  for i in np.arange(num_cols-1):
    j = i + 1
    while j < num_cols:
      col1 = X.columns.values[i]
      col2 = X.columns.values[j]
      if ('corona_silent' not in col1) | ('corona_silent' not in col2):
        newcol = col1+col2
        X[newcol] = X[col1] + X[col2]
      j += 1
  
  return X

# %% [markdown]
# # Simple Logistic Regression

# %%
# Cross Validated Logistic Regression
def simple_log_reg(X, Y):
  seed = 0
  test_size = 0.2
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)
  clf = LogisticRegressionCV(cv=10, random_state=0).fit(X_train, Y_train)

  # Compute Metrics
  fpr, tpr, thresholds = metrics.roc_curve(Y_test, clf.predict_proba(X_test)[:,1])
  auc1 = np.round(auc(fpr, tpr), 2)
  auc2 = np.round(roc_auc_score(Y_test, clf.predict_proba(X_test)[:,1]), 2)
  train_acc = np.round(clf.score(X_train, Y_train), 2)
  test_acc = np.round(clf.score(X_test, Y_test), 2)
  cm = confusion_matrix(Y_test, clf.predict(X_test))
  tn, fp, fn, tp = cm.ravel()
  precision = np.round(tp / (tp + fp), 2)
  recall = np.round(tp / (tp + fn), 2)

  print('AUC = ' + str(auc1))
  print('AUC_ROC = ' + str(auc2))
  print('Train accuracy = ' + str(train_acc))
  print('Test accuracy = ' + str(test_acc))

# %%
# Plot results of simple models (generated by function above)
models = ['Cold', 'Flu', 'Corona', 'Corona_Silent']
aucs = [0.53, 0.55, 0.55, 0.56]

auc_df = pd.DataFrame(data={'Model': models, 'Test AUC': aucs})
auc_df

# Simple Feature Logistic Regression
plt.figure(figsize=(14, 7))
g = sns.barplot(x="Model", y="Test AUC", data=auc_df);
for p in g.patches:
    g.annotate(format(p.get_height(), '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.ylim(0.4, 0.65)
plt.xlabel('Symptom')
plt.title('Test AUC of Simple Logistic Regression');

# %% [markdown]
# # More Exhaustive Logistic Regression
#
# Goal: Build a binary classifier that can predict "corona_test_result"

# %%
# Cross Validated Logistic Regression
def logistic_regression(X, Y):
  seed = 0
  test_size = 0.2
  X_train, X_test, Y_train, Y_test = train_test_split(X_simp, Y, test_size=test_size, random_state=seed)
  clf = LogisticRegressionCV(cv=10, random_state=0).fit(X_train, Y_train)

  # Compute Metrics
  fpr, tpr, thresholds = metrics.roc_curve(Y_test, clf.predict_proba(X_test)[:,1])
  auc1 = np.round(auc(fpr, tpr), 2)
  auc2 = np.round(roc_auc_score(Y_test, clf.predict_proba(X_test)[:,1]), 2)
  train_acc = np.round(clf.score(X_train, Y_train), 2)
  test_acc = np.round(clf.score(X_test, Y_test), 2)
  cm = confusion_matrix(Y_test, clf.predict(X_test))
  tn, fp, fn, tp = cm.ravel()
  precision = np.round(tp / (tp + fp), 2)
  recall = np.round(tp / (tp + fn), 2)

  print('AUC = ' + str(auc1))
  print('AUC_ROC = ' + str(auc2))
  print('Train accuracy = ' + str(train_acc))
  print('Test accuracy = ' + str(test_acc))

  # Plot ROC Curve
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))
  ax1.plot(fpr,tpr,label="AUC="+str(auc1))
  ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8);
  ax1.legend();
  ax1.set_xlabel('FPR')
  ax1.set_ylabel('TPR')
  ax1.set_title('ROC Curve for Logistic Regression Classifier');
  txt = 'Precision = ' + str(precision) + ', Recall = ' + str(recall)
  ax1.text(0.5, -0.2, txt, ha='center')

  # Plot Confusion Matrix
  sns.heatmap(pd.DataFrame(cm), annot=True, cmap="GnBu", ax=ax2);
  ax2.set_ylabel('True Label');
  ax2.set_xlabel('Predicted Label');
  ax2.set_title('Confusion Matrix for Logistic Regression Classifier');
  txt = 'Test Accuracy = ' + str(test_acc)
  ax2.text(1, 2.3, txt, ha='center');
# Out:
# AUC = 0.56
# AUC_ROC = 0.56
# Train accuracy = 0.67
# Test accuracy = 0.68

# %% [markdown]
# # Support Vector Classifier

# %%
# Create Universal Split
seed = 0
test_size = 0.2
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
# runs SVC given in X_train and Y_train
def sv_classifier(X_train, Y_train):
  # 10-fold cross-validation for SVC
seed = 0
svc = svm.SVC(kernel='rbf', probability=True)
svc.fit(X_train, Y_train)

# Compute AUC
probas_ = svc.predict_proba(X_test)
fpr, tpr, thresholds = roc_curve(Y_test, probas_[:, 1])
roc_auc = auc(fpr, tpr)
print(roc_auc)
# Out:
# [0.64428499 0.65532961 0.61940922 0.59704609 0.6402852  0.64820474
#  0.64869366 0.60424752 0.64872931 0.59549274]
# 0.6301723084218014

# %% [markdown]
# # K Nearest Neighbor

# %%
# run KNN given X and Y
def find_best_k(X, Y):
  # Check Cross Vals
  seed = 0
  test_size = 0.2
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

  # 10-fold cross-validation with K=5 for KNN (the n_neighbors parameter)
  knn = KNeighborsClassifier(n_neighbors=5)
  scores = cross_val_score(knn, X_train, Y_train, cv=10, scoring='roc_auc')
  print(scores)
  print(scores.mean())

  # search for an optimal value of K for KNN
  k_range = list(range(45, 81))
  k_scores = []
  best_k = 0
  best_score = 0
  for k in k_range:
      knn = KNeighborsClassifier(n_neighbors=k)
      scores = cross_val_score(knn, X_train, Y_train, cv=10, scoring='roc_auc')
      k_scores.append(scores.mean())
      if scores.mean() > best_score:
        best_score = scores.mean()
        best_k = k
  print(k_scores)

  # plot the value of K for KNN (x-axis) versus the cross-validated accuracy (y-axis)
  plt.plot(k_range, k_scores)
  plt.xlabel('Value of K for KNN')
  plt.ylabel('Cross-Validated AUC')

  return best_k
# Out:
# [0.62697769 0.58727181 0.57176471 0.59065444 0.57712758 0.61334861
#  0.54080978 0.60626942 0.60686529 0.5918411 ]
# 0.591293041981683

# %%
# 10-fold cross-validation with K=best_k for KNN (the n_neighbors parameter)
def run_knn(X_train, Y_train):
  seed = 0
  knn = KNeighborsClassifier(n_neighbors=59)
  scores = cross_val_score(knn, X_train, Y_train, cv=10, scoring='roc_auc')
  print(scores)
  print(scores.mean())

  knn.fit(X_train, Y_train)
  test_auc = knn.score(X_test, Y_test)
  print(test_auc)
# Out:
# [0.65735801 0.65574037 0.61283932 0.63888974 0.67179017 0.66594347
#  0.64995162 0.60601477 0.64920295 0.61362872]
# 0.6421359136130942
# 0.6946983546617916

# %%
# Build Bagged Logistic Regression Model
# takes in dataframe, # models, # folds, cv, probability threshold
### random_state for LogisticRegressionCV NOT random seed for the sampling

def Bootstrap_LogisticRegression(X_train, Y_train, X_test, Y_test, n_models, cv, threshold, random_state):
  # Recontstruct datframe
  df = X_train.copy()
  df['Y'] = Y_train
  # empty array for prediction probabilities
  predicted_probs = np.zeros(len(X_test))
  for i in np.arange(n_models):
    # get bootstrapped sample
    boot_sample = df.sample(n=len(df), replace=True)
    Y = df['Y']
    X = df.drop(['Y'], axis=1)
    # build model from bootstrap, predict and store probs
    model = LogisticRegressionCV(cv=cv, random_state=random_state).fit(X, Y)
    predictions = np.array(model.predict_proba(X_test)[:,1])
    predicted_probs = predicted_probs + predictions
  
  # average across all samples
  predicted_probs = predicted_probs / n_models

  # compute predictions and accuracy
  predictions = [1 if x >= threshold else 0 for x in predicted_probs]
  accuracy = sum(predictions == Y_test) / len(Y_test)

  # Compute Metrics
  fpr, tpr, thresholds = metrics.roc_curve(Y_test, predicted_probs)
  auc1 = np.round(auc(fpr, tpr), 2)
  print('AUC1 = ' + str(auc1))
  auc2 = np.round(roc_auc_score(Y_test, predicted_probs), 2)
  print('AUC2 = ' + str(auc2))
  train_acc = np.round(clf.score(X_train, Y_train), 2)
  test_acc = np.round(clf.score(X_test, Y_test), 2)
  print('Test acc = ' + str(train_acc))
  print('Train acc = ' + str(test_acc))
  cm = confusion_matrix(Y_test, clf.predict(X_test))
  tn, fp, fn, tp = cm.ravel()
  precision = np.round(tp / (tp + fp), 2)
  recall = np.round(tp / (tp + fn), 2)

  print('AUC = ' + str(auc1))
  print('AUC_ROC = ' + str(auc2))
  print('Train accuracy = ' + str(train_acc))
  print('Test accuracy = ' + str(test_acc))

  # Plot ROC Curve
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))
  ax1.plot(fpr,tpr,label="AUC="+str(auc1))
  ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',label='Chance', alpha=.8);
  ax1.legend();
  ax1.set_xlabel('FPR')
  ax1.set_ylabel('TPR')
  ax1.set_title('ROC Curve for Logistic Regression Classifier');
  txt = 'Precision = ' + str(precision) + ', Recall = ' + str(recall)
  ax1.text(0.5, -0.2, txt, ha='center')

  # Plot Confusion Matrix
  sns.heatmap(pd.DataFrame(cm), annot=True, cmap="GnBu", ax=ax2);
  ax2.set_ylabel('True Label');
  ax2.set_xlabel('Predicted Label');
  ax2.set_title('Confusion Matrix for Logistic Regression Classifier');
  txt = 'Test Accuracy = ' + str(test_acc)
  ax2.text(1, 2.3, txt, ha='center');

# %%
# Bagged Cross Validated Logistic Regression
seed = 0
cv = 10
## Hyperparameters
n_models = 25
threshold = 0.5

Bootstrap_LogisticRegression(X_train, Y_train, X_test, Y_test, n_models, cv, threshold, random_state=seed)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-c3c95b341ec1> in <module>()
#       5 threshold = 0.5
#       6
# ----> 7 bagged_predictions, bagged_accuracy = Bootstrap_LogisticRegression(X_train, Y_train, X_test, Y_test, n_models, cv, threshold, random_state=seed)
#
# <ipython-input-75-c0ca58aa1fed> in Bootstrap_LogisticRegression(X_train, Y_train, X_test, Y_test, n_models, cv, threshold, random_state)
#      15     X = df.drop(['Y'], axis=1)
#      16     # build model from bootstrap, predict and store probs
# ---> 17     model = LogisticRegressionCV(cv=cv, random_state=random_state).fit(X, Y)
#      18     predictions = np.array(model.predict_proba(X_test)[:,1])
#      19     predicted_probs = predicted_probs + predictions
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    2083                       l1_ratio=l1_ratio
#    2084                       )
# -> 2085             for label in iter_encoded_labels
#    2086             for train, test in folds
#    2087             for l1_ratio in l1_ratios_)
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in _log_reg_scoring_path(X, y, train, test, pos_class, Cs, scoring, fit_intercept, max_iter, tol, class_weight, verbose, solver, penalty, dual, intercept_scaling, multi_class, random_state, max_squared_sum, sample_weight, l1_ratio)
#    1150         penalty=penalty, intercept_scaling=intercept_scaling,
#    1151         random_state=random_state, check_input=False,
# -> 1152         max_squared_sum=max_squared_sum, sample_weight=sample_weight)
#    1153
#    1154     log_reg = LogisticRegression(solver=solver, multi_class=multi_class)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     934                 func, w0, method="L-BFGS-B", jac=True,
#     935                 args=(X, target, 1. / C, sample_weight),
# --> 936                 options={"iprint": iprint, "gtol": tol, "maxiter": max_iter}
#     937             )
#     938             n_iter_i = _check_optimize_result(
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     elif meth == 'l-bfgs-b':
#     609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in _logistic_loss_and_grad(w, X, y, alpha, sample_weight)
#     116     grad = np.empty_like(w)
#     117
# --> 118     w, c, yz = _intercept_dot(w, X, y)
#     119
#     120     if sample_weight is None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in _intercept_dot(w, X, y)
#      79         w = w[:-1]
#      80
# ---> 81     z = safe_sparse_dot(X, w) + c
#      82     yz = y * z
#      83     return w, c, yz
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     149             ret = np.dot(a, b)
#     150     else:
# --> 151         ret = a @ b
#     152
#     153     if (sparse.issparse(a) and sparse.issparse(b)
#
# KeyboardInterrupt:

# %% [markdown]
# # XgBoost

# %%
def calculate_scores(tn,fp, fn, tp):
    sens = tp / (tp+fn)
    spec = tn / (tn+fp)
    ppv = tp / (tp + fp)
    npv = tn / (tn + fn)
    lr_pos = sens / (1-spec)
    lr_neg =  (1-sens)/ spec
    dor = (lr_pos)/(lr_neg)
    return sens, spec, ppv, npv, lr_pos, lr_neg, dor
#test case
calculate_scores(0.2, 0.7, 0.8, 0.2)
## split data into train and test sets
seed = 42
test_size = 0.2
def run_algo(X, Y, depth, lamb, pos_weight):
    # @param, X: training matrix
    # @param, Y: label vector
    # @param, depth: max_depth of each tree
    # @param, lamb: bias hyperparameter
    # @param, pos_weight: used to balance classes
    input_X = X
    X = np.matrix(X)[:,1:]
    Y = np.array([int(np.floor(i)) for i in Y])
    print('Starting 5-fold cross-validation...')
    senses, specs, ppvs, npvs, lr_poses, lr_negs, dors, aucs, auprcs = ([] for i in range(9)) 
    kf = StratifiedKFold(n_splits= 10, shuffle=True, random_state=seed)
    for train_index, test_index in kf.split(X, Y):
        X_train, X_test = X[train_index], X[test_index]
        Y_train, Y_test = Y[train_index], Y[test_index]
        model = XGBClassifier(max_depth=depth, reg_lambda=lamb, reg_alpha=0, scale_pos_weight=pos_weight, seed=3)
        model.fit(X_train, Y_train, eval_metric='logloss', early_stopping_rounds = 5, eval_set=[(X_test, Y_test)])
        preds = model.predict(X_test)
        tn, fp, fn, tp = confusion_matrix(Y_test, preds).ravel()
        scores = calculate_scores(tn, fp, fn, tp)
        model_features = model.feature_importances_
        fpr, tpr, thresholds = metrics.roc_curve(Y_test, model.predict_proba(X_test)[:,1])
        auc = roc_auc_score(Y_test, model.predict(X_test))
        auprc = average_precision_score(Y_test, model.predict(X_test))
        senses.append(scores[0])
        specs.append(scores[1])
        ppvs.append(scores[2])
        npvs.append(scores[3])
        lr_poses.append(scores[4])
        lr_negs.append(scores[5])
        dors.append(scores[6])
        aucs.append(auc)
        auprcs.append(auprc)    
    print('Predictions done.')
    #reporting these scores for the last fold of cross-validation only
    print('Number of true positives: ', tp)
    print('Number of false positives: ', fp)
    print('Number of true negatives: ', tn)
    print('Number of false negatives: ', fn)
    #print('confusion matrix', [PPV,NPV,tn,fp,fn,tp])
    print('params', depth,lamb, pos_weight)
    #reporting average across all folds for these
    print('sens', np.mean(senses))
    print('spec', np.mean(specs))
    print('ppv', np.mean(ppvs))
    print('npv', np.mean(npvs))
    print('auroc', np.mean(aucs))
    print('auroc std dev', np.std(aucs))
    print('LR+', np.mean(lr_poses))
    print('LR-', np.mean(lr_negs))
    print('DOR', np.mean(dors))
    print('auprc', np.mean(auprcs))
    print('total number of positive encounters', sum(Y_train)+sum(Y_test))
    print('total number of negative encounters', len(Y_train) + len(Y_test))
    #refitting with original matrix to preserve feature labels
    X_train, X_test, Y_train, Y_test = train_test_split(input_X, Y, test_size=test_size, random_state=seed)
    model = XGBClassifier(max_depth=depth, reg_lambda=lamb, reg_alpha=0, scale_pos_weight=pos_weight, seed=3)
    model.fit(X_train, Y_train, eval_metric='logloss',
              early_stopping_rounds = 5, eval_set=[(X_test, Y_test)], verbose = False)
    model_features = model.feature_importances_
    #print('Feature Importances', model_features)
    ax = plot_importance(model, importance_type = 'weight', max_num_features = 20)
    #ax.figure.savefig('models/best_model/fp_fig_' + model_name)
    display(ax)
    return fpr, tpr, np.mean(aucs), model, [np.mean(ppvs),np.mean(npvs),tn,fp,fn,tp]

# %%
fpr, tpr, auc, model, confusion = run_algo(X.astype('float64'), Y, 4, 100, 2)
# Out:
# Starting 5-fold cross-validation...
# [0]	validation_0-logloss:0.690169
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.687098
# [2]	validation_0-logloss:0.68511
# [3]	validation_0-logloss:0.68263
# [4]	validation_0-logloss:0.681137
# [5]	validation_0-logloss:0.679679
# [6]	validation_0-logloss:0.678047
# [7]	validation_0-logloss:0.676825
# [8]	validation_0-logloss:0.675534
# [9]	validation_0-logloss:0.674443
# [10]	validation_0-logloss:0.673668
# [11]	validation_0-logloss:0.672774
# [12]	validation_0-logloss:0.671943
# [13]	validation_0-logloss:0.671639
# [14]	validation_0-logloss:0.670784
# [15]	validation_0-logloss:0.670253
# [16]	validation_0-logloss:0.669934
# [17]	validation_0-logloss:0.669492
# [18]	validation_0-logloss:0.669199
# [19]	validation_0-logloss:0.669042
# [20]	validation_0-logloss:0.668637
# [21]	validation_0-logloss:0.66843
# [22]	validation_0-logloss:0.667977
# [23]	validation_0-logloss:0.667594
# [24]	validation_0-logloss:0.667262
# [25]	validation_0-logloss:0.667051
# [26]	validation_0-logloss:0.667016
# [27]	validation_0-logloss:0.666755
# [28]	validation_0-logloss:0.666575
# [29]	validation_0-logloss:0.666369
# [30]	validation_0-logloss:0.666181
# [31]	validation_0-logloss:0.666137
# [32]	validation_0-logloss:0.666141
# [33]	validation_0-logloss:0.666156
# [34]	validation_0-logloss:0.666125
# [35]	validation_0-logloss:0.666298
# [36]	validation_0-logloss:0.666098
# [37]	validation_0-logloss:0.666167
# [38]	validation_0-logloss:0.666228
# [39]	validation_0-logloss:0.665798
# [40]	validation_0-logloss:0.665644
# [41]	validation_0-logloss:0.665407
# [42]	validation_0-logloss:0.665073
# [43]	validation_0-logloss:0.664831
# [44]	validation_0-logloss:0.664655
# [45]	validation_0-logloss:0.664372
# [46]	validation_0-logloss:0.664136
# [47]	validation_0-logloss:0.664026
# [48]	validation_0-logloss:0.66387
# [49]	validation_0-logloss:0.663938
# [50]	validation_0-logloss:0.663852
# [51]	validation_0-logloss:0.663906
# [52]	validation_0-logloss:0.663689
# [53]	validation_0-logloss:0.663739
# [54]	validation_0-logloss:0.663759
# [55]	validation_0-logloss:0.66378
# [56]	validation_0-logloss:0.663586
# [57]	validation_0-logloss:0.663349
# [58]	validation_0-logloss:0.663173
# [59]	validation_0-logloss:0.663225
# [60]	validation_0-logloss:0.663162
# [61]	validation_0-logloss:0.663175
# [62]	validation_0-logloss:0.663187
# [63]	validation_0-logloss:0.6632
# [64]	validation_0-logloss:0.663011
# [65]	validation_0-logloss:0.662839
# [66]	validation_0-logloss:0.662907
# [67]	validation_0-logloss:0.662712
# [68]	validation_0-logloss:0.662728
# [69]	validation_0-logloss:0.662754
# [70]	validation_0-logloss:0.662781
# [71]	validation_0-logloss:0.662751
# [72]	validation_0-logloss:0.662766
# Stopping. Best iteration:
# [67]	validation_0-logloss:0.662712
#
# [0]	validation_0-logloss:0.69033
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.688184
# [2]	validation_0-logloss:0.686443
# [3]	validation_0-logloss:0.684898
# [4]	validation_0-logloss:0.68319
# [5]	validation_0-logloss:0.68202
# [6]	validation_0-logloss:0.680762
# [7]	validation_0-logloss:0.679446
# [8]	validation_0-logloss:0.678334
# [9]	validation_0-logloss:0.677558
# [10]	validation_0-logloss:0.67692
# [11]	validation_0-logloss:0.676265
# [12]	validation_0-logloss:0.675966
# [13]	validation_0-logloss:0.675619
# [14]	validation_0-logloss:0.675352
# [15]	validation_0-logloss:0.6749
# [16]	validation_0-logloss:0.674717
# [17]	validation_0-logloss:0.67431
# [18]	validation_0-logloss:0.67375
# [19]	validation_0-logloss:0.67375
# [20]	validation_0-logloss:0.673185
# [21]	validation_0-logloss:0.673167
# [22]	validation_0-logloss:0.673153
# [23]	validation_0-logloss:0.673182
# [24]	validation_0-logloss:0.673123
# [25]	validation_0-logloss:0.672631
# [26]	validation_0-logloss:0.672685
# [27]	validation_0-logloss:0.672718
# [28]	validation_0-logloss:0.672327
# [29]	validation_0-logloss:0.671968
# [30]	validation_0-logloss:0.672067
# [31]	validation_0-logloss:0.67217
# [32]	validation_0-logloss:0.671861
# [33]	validation_0-logloss:0.67198
# [34]	validation_0-logloss:0.671686
# [35]	validation_0-logloss:0.671785
# [36]	validation_0-logloss:0.671771
# [37]	validation_0-logloss:0.671883
# [38]	validation_0-logloss:0.67199
# [39]	validation_0-logloss:0.671939
# Stopping. Best iteration:
# [34]	validation_0-logloss:0.671686
#
# [0]	validation_0-logloss:0.690619
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.688327
# [2]	validation_0-logloss:0.686486
# [3]	validation_0-logloss:0.685286
# [4]	validation_0-logloss:0.684196
# [5]	validation_0-logloss:0.682717
# [6]	validation_0-logloss:0.681668
# [7]	validation_0-logloss:0.680675
# [8]	validation_0-logloss:0.679776
# [9]	validation_0-logloss:0.679368
# [10]	validation_0-logloss:0.678635
# [11]	validation_0-logloss:0.677998
# [12]	validation_0-logloss:0.677887
# [13]	validation_0-logloss:0.67743
# [14]	validation_0-logloss:0.677162
# [15]	validation_0-logloss:0.67683
# [16]	validation_0-logloss:0.676548
# [17]	validation_0-logloss:0.676374
# [18]	validation_0-logloss:0.676087
# [19]	validation_0-logloss:0.676003
# [20]	validation_0-logloss:0.675965
# [21]	validation_0-logloss:0.675754
# [22]	validation_0-logloss:0.6755
# [23]	validation_0-logloss:0.675453
# [24]	validation_0-logloss:0.675568
# [25]	validation_0-logloss:0.675613
# [26]	validation_0-logloss:0.675496
# [27]	validation_0-logloss:0.675415
# [28]	validation_0-logloss:0.675166
# [29]	validation_0-logloss:0.67516
# [30]	validation_0-logloss:0.675271
# [31]	validation_0-logloss:0.675071
# [32]	validation_0-logloss:0.675065
# [33]	validation_0-logloss:0.67497
# [34]	validation_0-logloss:0.675071
# [35]	validation_0-logloss:0.67524
# [36]	validation_0-logloss:0.675246
# [37]	validation_0-logloss:0.675422
# [38]	validation_0-logloss:0.675493
# Stopping. Best iteration:
# [33]	validation_0-logloss:0.67497
#
# [0]	validation_0-logloss:0.689825
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.687059
# [2]	validation_0-logloss:0.68464
# [3]	validation_0-logloss:0.682235
# [4]	validation_0-logloss:0.680107
# [5]	validation_0-logloss:0.677857
# [6]	validation_0-logloss:0.675966
# [7]	validation_0-logloss:0.674166
# [8]	validation_0-logloss:0.672508
# [9]	validation_0-logloss:0.67111
# [10]	validation_0-logloss:0.669553
# [11]	validation_0-logloss:0.668431
# [12]	validation_0-logloss:0.66758
# [13]	validation_0-logloss:0.666587
# [14]	validation_0-logloss:0.665336
# [15]	validation_0-logloss:0.664364
# [16]	validation_0-logloss:0.663508
# [17]	validation_0-logloss:0.662848
# [18]	validation_0-logloss:0.662378
# [19]	validation_0-logloss:0.661703
# [20]	validation_0-logloss:0.660948
# [21]	validation_0-logloss:0.660524
# [22]	validation_0-logloss:0.659892
# [23]	validation_0-logloss:0.659217
# [24]	validation_0-logloss:0.658789
# [25]	validation_0-logloss:0.658651
# [26]	validation_0-logloss:0.658207
# [27]	validation_0-logloss:0.658047
# [28]	validation_0-logloss:0.657929
# [29]	validation_0-logloss:0.657547
# [30]	validation_0-logloss:0.65713
# [31]	validation_0-logloss:0.657016
# [32]	validation_0-logloss:0.656674
# [33]	validation_0-logloss:0.656566
# [34]	validation_0-logloss:0.656465
# [35]	validation_0-logloss:0.656154
# [36]	validation_0-logloss:0.655964
# [37]	validation_0-logloss:0.655805
# [38]	validation_0-logloss:0.655727
# [39]	validation_0-logloss:0.655527
# [40]	validation_0-logloss:0.655452
# [41]	validation_0-logloss:0.655331
# [42]	validation_0-logloss:0.655251
# [43]	validation_0-logloss:0.655003
# [44]	validation_0-logloss:0.654929
# [45]	validation_0-logloss:0.654654
# [46]	validation_0-logloss:0.654627
# [47]	validation_0-logloss:0.654382
# [48]	validation_0-logloss:0.654303
# [49]	validation_0-logloss:0.654031
# [50]	validation_0-logloss:0.653845
# [51]	validation_0-logloss:0.653461
# [52]	validation_0-logloss:0.653365
# [53]	validation_0-logloss:0.653207
# [54]	validation_0-logloss:0.65291
# [55]	validation_0-logloss:0.652811
# [56]	validation_0-logloss:0.65247
# [57]	validation_0-logloss:0.652351
# [58]	validation_0-logloss:0.652282
# [59]	validation_0-logloss:0.652118
# [60]	validation_0-logloss:0.651956
# [61]	validation_0-logloss:0.65192
# [62]	validation_0-logloss:0.651798
# [63]	validation_0-logloss:0.65147
# [64]	validation_0-logloss:0.651406
# [65]	validation_0-logloss:0.651342
# [66]	validation_0-logloss:0.651174
# [67]	validation_0-logloss:0.651011
# [68]	validation_0-logloss:0.650972
# [69]	validation_0-logloss:0.650909
# [70]	validation_0-logloss:0.650801
# [71]	validation_0-logloss:0.650746
# [72]	validation_0-logloss:0.650569
# [73]	validation_0-logloss:0.650402
# [74]	validation_0-logloss:0.650101
# [75]	validation_0-logloss:0.649938
# [76]	validation_0-logloss:0.649819
# [77]	validation_0-logloss:0.64974
# [78]	validation_0-logloss:0.649758
# [79]	validation_0-logloss:0.649479
# [80]	validation_0-logloss:0.649273
# [81]	validation_0-logloss:0.649064
# [82]	validation_0-logloss:0.648982
# [83]	validation_0-logloss:0.648788
# [84]	validation_0-logloss:0.648574
# [85]	validation_0-logloss:0.648544
# [86]	validation_0-logloss:0.648466
# [87]	validation_0-logloss:0.648425
# [88]	validation_0-logloss:0.648249
# [89]	validation_0-logloss:0.648236
# [90]	validation_0-logloss:0.648229
# [91]	validation_0-logloss:0.648054
# [92]	validation_0-logloss:0.647934
# [93]	validation_0-logloss:0.647758
# [94]	validation_0-logloss:0.64758
# [95]	validation_0-logloss:0.647409
# [96]	validation_0-logloss:0.647359
# [97]	validation_0-logloss:0.647232
# [98]	validation_0-logloss:0.64719
# [99]	validation_0-logloss:0.647219
# [0]	validation_0-logloss:0.690086
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.687196
# [2]	validation_0-logloss:0.684985
# [3]	validation_0-logloss:0.683284
# [4]	validation_0-logloss:0.681718
# [5]	validation_0-logloss:0.680219
# [6]	validation_0-logloss:0.678374
# [7]	validation_0-logloss:0.67644
# [8]	validation_0-logloss:0.674755
# [9]	validation_0-logloss:0.673883
# [10]	validation_0-logloss:0.672919
# [11]	validation_0-logloss:0.671638
# [12]	validation_0-logloss:0.670873
# [13]	validation_0-logloss:0.670025
# [14]	validation_0-logloss:0.66961
# [15]	validation_0-logloss:0.669205
# [16]	validation_0-logloss:0.66879
# [17]	validation_0-logloss:0.668537
# [18]	validation_0-logloss:0.668352
# [19]	validation_0-logloss:0.668048
# [20]	validation_0-logloss:0.667857
# [21]	validation_0-logloss:0.667455
# [22]	validation_0-logloss:0.667286
# [23]	validation_0-logloss:0.667036
# [24]	validation_0-logloss:0.666811
# [25]	validation_0-logloss:0.666301
# [26]	validation_0-logloss:0.66589
# [27]	validation_0-logloss:0.665453
# [28]	validation_0-logloss:0.6651
# [29]	validation_0-logloss:0.664921
# [30]	validation_0-logloss:0.664483
# [31]	validation_0-logloss:0.664433
# [32]	validation_0-logloss:0.664272
# [33]	validation_0-logloss:0.663964
# [34]	validation_0-logloss:0.66396
# [35]	validation_0-logloss:0.663694
# [36]	validation_0-logloss:0.663687
# [37]	validation_0-logloss:0.663445
# [38]	validation_0-logloss:0.663178
# [39]	validation_0-logloss:0.662983
# [40]	validation_0-logloss:0.66303
# [41]	validation_0-logloss:0.663075
# [42]	validation_0-logloss:0.663137
# [43]	validation_0-logloss:0.663195
# [44]	validation_0-logloss:0.663252
# Stopping. Best iteration:
# [39]	validation_0-logloss:0.662983
#
# [0]	validation_0-logloss:0.690192
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.68726
# [2]	validation_0-logloss:0.685036
# [3]	validation_0-logloss:0.683214
# [4]	validation_0-logloss:0.68083
# [5]	validation_0-logloss:0.679185
# [6]	validation_0-logloss:0.678069
# [7]	validation_0-logloss:0.676591
# [8]	validation_0-logloss:0.674982
# [9]	validation_0-logloss:0.673499
# [10]	validation_0-logloss:0.672921
# [11]	validation_0-logloss:0.671785
# [12]	validation_0-logloss:0.67094
# [13]	validation_0-logloss:0.670543
# [14]	validation_0-logloss:0.669871
# [15]	validation_0-logloss:0.669351
# [16]	validation_0-logloss:0.669059
# [17]	validation_0-logloss:0.668546
# [18]	validation_0-logloss:0.668253
# [19]	validation_0-logloss:0.667784
# [20]	validation_0-logloss:0.667367
# [21]	validation_0-logloss:0.666818
# [22]	validation_0-logloss:0.66635
# [23]	validation_0-logloss:0.666025
# [24]	validation_0-logloss:0.665691
# [25]	validation_0-logloss:0.66562
# [26]	validation_0-logloss:0.665217
# [27]	validation_0-logloss:0.6649
# [28]	validation_0-logloss:0.664571
# [29]	validation_0-logloss:0.664405
# [30]	validation_0-logloss:0.664127
# [31]	validation_0-logloss:0.664068
# [32]	validation_0-logloss:0.663852
# [33]	validation_0-logloss:0.663661
# [34]	validation_0-logloss:0.663532
# [35]	validation_0-logloss:0.663379
# [36]	validation_0-logloss:0.663317
# [37]	validation_0-logloss:0.663116
# [38]	validation_0-logloss:0.663012
# [39]	validation_0-logloss:0.662825
# [40]	validation_0-logloss:0.662812
# [41]	validation_0-logloss:0.662581
# [42]	validation_0-logloss:0.662373
# [43]	validation_0-logloss:0.662238
# [44]	validation_0-logloss:0.662137
# [45]	validation_0-logloss:0.662087
# [46]	validation_0-logloss:0.661787
# [47]	validation_0-logloss:0.661679
# [48]	validation_0-logloss:0.661455
# [49]	validation_0-logloss:0.661171
# [50]	validation_0-logloss:0.661098
# [51]	validation_0-logloss:0.661018
# [52]	validation_0-logloss:0.660872
# [53]	validation_0-logloss:0.660658
# [54]	validation_0-logloss:0.660645
# [55]	validation_0-logloss:0.660551
# [56]	validation_0-logloss:0.660547
# [57]	validation_0-logloss:0.660477
# [58]	validation_0-logloss:0.660302
# [59]	validation_0-logloss:0.660165
# [60]	validation_0-logloss:0.660041
# [61]	validation_0-logloss:0.659893
# [62]	validation_0-logloss:0.659871
# [63]	validation_0-logloss:0.659831
# [64]	validation_0-logloss:0.659853
# [65]	validation_0-logloss:0.659726
# [66]	validation_0-logloss:0.659612
# [67]	validation_0-logloss:0.659576
# [68]	validation_0-logloss:0.659488
# [69]	validation_0-logloss:0.659388
# [70]	validation_0-logloss:0.659213
# [71]	validation_0-logloss:0.659123
# [72]	validation_0-logloss:0.659037
# [73]	validation_0-logloss:0.659029
# [74]	validation_0-logloss:0.658919
# [75]	validation_0-logloss:0.658967
# [76]	validation_0-logloss:0.658991
# [77]	validation_0-logloss:0.659087
# [78]	validation_0-logloss:0.659141
# [79]	validation_0-logloss:0.659194
# Stopping. Best iteration:
# [74]	validation_0-logloss:0.658919
#
# [0]	validation_0-logloss:0.689946
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.687165
# [2]	validation_0-logloss:0.684697
# [3]	validation_0-logloss:0.682841
# [4]	validation_0-logloss:0.680801
# [5]	validation_0-logloss:0.678961
# [6]	validation_0-logloss:0.677562
# [7]	validation_0-logloss:0.676426
# [8]	validation_0-logloss:0.675086
# [9]	validation_0-logloss:0.673943
# [10]	validation_0-logloss:0.673008
# [11]	validation_0-logloss:0.672571
# [12]	validation_0-logloss:0.672089
# [13]	validation_0-logloss:0.671733
# [14]	validation_0-logloss:0.671323
# [15]	validation_0-logloss:0.670907
# [16]	validation_0-logloss:0.670505
# [17]	validation_0-logloss:0.670241
# [18]	validation_0-logloss:0.670098
# [19]	validation_0-logloss:0.669999
# [20]	validation_0-logloss:0.669731
# [21]	validation_0-logloss:0.669686
# [22]	validation_0-logloss:0.669507
# [23]	validation_0-logloss:0.669431
# [24]	validation_0-logloss:0.669209
# [25]	validation_0-logloss:0.669117
# [26]	validation_0-logloss:0.669054
# [27]	validation_0-logloss:0.668904
# [28]	validation_0-logloss:0.668862
# [29]	validation_0-logloss:0.66896
# [30]	validation_0-logloss:0.66906
# [31]	validation_0-logloss:0.669019
# [32]	validation_0-logloss:0.668938
# [33]	validation_0-logloss:0.668966
# Stopping. Best iteration:
# [28]	validation_0-logloss:0.668862
#
# [0]	validation_0-logloss:0.689964
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.687944
# [2]	validation_0-logloss:0.686592
# [3]	validation_0-logloss:0.684274
# [4]	validation_0-logloss:0.683321
# [5]	validation_0-logloss:0.682054
# [6]	validation_0-logloss:0.680554
# [7]	validation_0-logloss:0.67963
# [8]	validation_0-logloss:0.678905
# [9]	validation_0-logloss:0.678312
# [10]	validation_0-logloss:0.677768
# [11]	validation_0-logloss:0.677073
# [12]	validation_0-logloss:0.676661
# [13]	validation_0-logloss:0.676158
# [14]	validation_0-logloss:0.675873
# [15]	validation_0-logloss:0.675685
# [16]	validation_0-logloss:0.675311
# [17]	validation_0-logloss:0.675057
# [18]	validation_0-logloss:0.674808
# [19]	validation_0-logloss:0.674544
# [20]	validation_0-logloss:0.674172
# [21]	validation_0-logloss:0.674153
# [22]	validation_0-logloss:0.674218
# [23]	validation_0-logloss:0.673877
# [24]	validation_0-logloss:0.673834
# [25]	validation_0-logloss:0.673552
# [26]	validation_0-logloss:0.673442
# [27]	validation_0-logloss:0.67341
# [28]	validation_0-logloss:0.673192
# [29]	validation_0-logloss:0.673355
# [30]	validation_0-logloss:0.673556
# [31]	validation_0-logloss:0.673768
# [32]	validation_0-logloss:0.673794
# [33]	validation_0-logloss:0.673589
# Stopping. Best iteration:
# [28]	validation_0-logloss:0.673192
#
# [0]	validation_0-logloss:0.690434
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.68855
# [2]	validation_0-logloss:0.686632
# [3]	validation_0-logloss:0.684792
# [4]	validation_0-logloss:0.683464
# [5]	validation_0-logloss:0.682164
# [6]	validation_0-logloss:0.680767
# [7]	validation_0-logloss:0.679592
# [8]	validation_0-logloss:0.678574
# [9]	validation_0-logloss:0.677822
# [10]	validation_0-logloss:0.676579
# [11]	validation_0-logloss:0.675495
# [12]	validation_0-logloss:0.674586
# [13]	validation_0-logloss:0.674252
# [14]	validation_0-logloss:0.673783
# [15]	validation_0-logloss:0.673823
# [16]	validation_0-logloss:0.673245
# [17]	validation_0-logloss:0.672772
# [18]	validation_0-logloss:0.672366
# [19]	validation_0-logloss:0.672351
# [20]	validation_0-logloss:0.672053
# [21]	validation_0-logloss:0.671761
# [22]	validation_0-logloss:0.671818
# [23]	validation_0-logloss:0.671602
# [24]	validation_0-logloss:0.671416
# [25]	validation_0-logloss:0.671216
# [26]	validation_0-logloss:0.671064
# [27]	validation_0-logloss:0.670933
# [28]	validation_0-logloss:0.670785
# [29]	validation_0-logloss:0.670796
# [30]	validation_0-logloss:0.67084
# [31]	validation_0-logloss:0.670928
# [32]	validation_0-logloss:0.670883
# [33]	validation_0-logloss:0.67093
# Stopping. Best iteration:
# [28]	validation_0-logloss:0.670785
#
# [0]	validation_0-logloss:0.689444
# Will train until validation_0-logloss hasn't improved in 5 rounds.
# [1]	validation_0-logloss:0.686976
# [2]	validation_0-logloss:0.684897
# [3]	validation_0-logloss:0.682865
# [4]	validation_0-logloss:0.680524
# [5]	validation_0-logloss:0.678488
# [6]	validation_0-logloss:0.677446
# [7]	validation_0-logloss:0.675311
# [8]	validation_0-logloss:0.673583
# [9]	validation_0-logloss:0.672093
# [10]	validation_0-logloss:0.670537
# [11]	validation_0-logloss:0.669996
# [12]	validation_0-logloss:0.668884
# [13]	validation_0-logloss:0.668345
# [14]	validation_0-logloss:0.667904
# [15]	validation_0-logloss:0.667479
# [16]	validation_0-logloss:0.666723
# [17]	validation_0-logloss:0.665891
# [18]	validation_0-logloss:0.665362
# [19]	validation_0-logloss:0.664718
# [20]	validation_0-logloss:0.664286
# [21]	validation_0-logloss:0.663739
# [22]	validation_0-logloss:0.663137
# [23]	validation_0-logloss:0.66264
# [24]	validation_0-logloss:0.662159
# [25]	validation_0-logloss:0.661791
# [26]	validation_0-logloss:0.661452
# [27]	validation_0-logloss:0.661163
# [28]	validation_0-logloss:0.660984
# [29]	validation_0-logloss:0.660604
# [30]	validation_0-logloss:0.660333
# [31]	validation_0-logloss:0.660103
# [32]	validation_0-logloss:0.659768
# [33]	validation_0-logloss:0.659638
# [34]	validation_0-logloss:0.659622
# [35]	validation_0-logloss:0.659469
# [36]	validation_0-logloss:0.65926
# [37]	validation_0-logloss:0.659057
# [38]	validation_0-logloss:0.658971
# [39]	validation_0-logloss:0.658956
# [40]	validation_0-logloss:0.658814
# [41]	validation_0-logloss:0.658695
# [42]	validation_0-logloss:0.658686
# [43]	validation_0-logloss:0.658659
# [44]	validation_0-logloss:0.658661
# [45]	validation_0-logloss:0.658679
# [46]	validation_0-logloss:0.658638
# [47]	validation_0-logloss:0.658589
# [48]	validation_0-logloss:0.658487
# [49]	validation_0-logloss:0.658293
# [50]	validation_0-logloss:0.658206
# [51]	validation_0-logloss:0.658122
# [52]	validation_0-logloss:0.658138
# [53]	validation_0-logloss:0.6581
# [54]	validation_0-logloss:0.658054
# [55]	validation_0-logloss:0.657992
# [56]	validation_0-logloss:0.657811
# [57]	validation_0-logloss:0.657683
# [58]	validation_0-logloss:0.657515
# [59]	validation_0-logloss:0.657526
# [60]	validation_0-logloss:0.657376
# [61]	validation_0-logloss:0.657257
# [62]	validation_0-logloss:0.657064
# [63]	validation_0-logloss:0.657044
# [64]	validation_0-logloss:0.656878
# [65]	validation_0-logloss:0.656727
# [66]	validation_0-logloss:0.656778
# [67]	validation_0-logloss:0.656617
# [68]	validation_0-logloss:0.656621
# [69]	validation_0-logloss:0.656477
# [70]	validation_0-logloss:0.656536
# [71]	validation_0-logloss:0.656616
# [72]	validation_0-logloss:0.656475
# [73]	validation_0-logloss:0.656534
# [74]	validation_0-logloss:0.656491
# [75]	validation_0-logloss:0.656423
# [76]	validation_0-logloss:0.656386
# [77]	validation_0-logloss:0.656354
# [78]	validation_0-logloss:0.656537
# [79]	validation_0-logloss:0.656473
# [80]	validation_0-logloss:0.656533
# [81]	validation_0-logloss:0.656408
# [82]	validation_0-logloss:0.656279
# [83]	validation_0-logloss:0.656229
# [84]	validation_0-logloss:0.656201
# [85]	validation_0-logloss:0.656182
# [86]	validation_0-logloss:0.656066
# [87]	validation_0-logloss:0.656015
# [88]	validation_0-logloss:0.656201
# [89]	validation_0-logloss:0.656179
# [90]	validation_0-logloss:0.656186
# [91]	validation_0-logloss:0.656233
# [92]	validation_0-logloss:0.656125
# Stopping. Best iteration:
# [87]	validation_0-logloss:0.656015
#
# Predictions done.
# Number of true positives:  156
# Number of false positives:  194
# Number of true negatives:  339
# Number of false negatives:  131
# params 4 100 2
# sens 0.47804878048780486
# spec 0.6994136082242413
# ppv 0.4613042594861807
# npv 0.7137276537975945
# auroc 0.5887311943560231
# auroc std dev 0.011657254711452642
# LR+ 1.593476097124014
# LR- 0.7457917854999574
# DOR 2.1449114320150264
# auprc 0.403273481498173
# total number of positive encounters 2870
# total number of negative encounters 8203

# %%
#Double Checking Model Results
fpr, tpr, thresholds = metrics.roc_curve(Y_test, model.predict_proba(X_test)[:,1])
auc = roc_auc_score(Y_test, model.predict(X_test))
auc
# Out:
# 0.5998222778224565

# %%
# Final Model Results
design_matrix_types = ['Initial Symptoms'] * 5 + ['Symptoms and Interactions'] * 5 + ['Symptoms, Time, and Country'] * 5
models = ['KNN', 'Logistic Regression', 'SVC', 'XG Boost', 'Bagged Logistic Regression'] * 3
# Results taken from sequential runs of the code above
aucs = [0.69, 0.56, 0.59, 0.60, 0.56, 0.70, 0.56, 0.59, 0.60, 0.66, 0.72, 0.75, 0.59, 0.70, 0.71]

auc_df = pd.DataFrame(data={'Feature Types':design_matrix_types, 'Model': models, 'Test AUC': aucs})
auc_df
# Out:
#                   Feature Types                       Model  Test AUC
# 0              Initial Symptoms                         KNN      0.69
# 1              Initial Symptoms         Logistic Regression      0.56
# 2              Initial Symptoms                         SVC      0.59
# 3              Initial Symptoms                    XG Boost      0.60
# 4              Initial Symptoms  Bagged Logistic Regression      0.56
# 5     Symptoms and Interactions                         KNN      0.70
# 6     Symptoms and Interactions         Logistic Regression      0.56
# 7     Symptoms and Interactions                         SVC      0.59
# 8     Symptoms and Interactions                    XG Boost      0.60
# 9     Symptoms and Interactions  Bagged Logistic Regression      0.66
# 10  Symptoms, Time, and Country                         KNN      0.72
# 11  Symptoms, Time, and Country         Logistic Regression      0.75
# 12  Symptoms, Time, and Country                         SVC      0.59
# 13  Symptoms, Time, and Country                    XG Boost      0.70
# 14  Symptoms, Time, and Country  Bagged Logistic Regression      0.71

# %%
# Plot Final Model Results
plt.figure(figsize=(14, 7))
g = sns.barplot(x="Model", y="Test AUC", hue='Feature Types', data=auc_df);
for p in g.patches:
    g.annotate(format(p.get_height(), '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.ylim(0.5, 0.8)
plt.title('Test AUC achieved across different model architecture');
